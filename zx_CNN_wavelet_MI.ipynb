# %% [markdown]
# # 基于小波变换和卷积神经网络的脑电运动成像信号分类
# ## 数据集
# 数据集A是来自BCI竞赛ii的数据集III。从一名正常受试者(女性，25岁)进行记录。 本实验共280次试验，每次试验时间为9s，每次试验间隔时间为0.5s ~ 2s。 前2s比较安静，在t=2s时，听觉刺激表示试验开始，1s处出现十字“+”;然后在t=3s时，显示箭头(向左或向右)作为提示。 同时，要求被试按照箭头指示进行意象任务。采样频率为128Hz，滤波频率为0.5 ~ 30hz
#
# 数据集B有9个受试者，四个运动想象任务，即左手、右手、舌头和双脚。一个目标记录两个sessions,每个sessions包含6个run，中间有短暂的休息。 一次run包括48个实验，（4个类 4*12），每个sessions包括288次实验。 在试验开始时(t=0)，一个注视十字出现在黑色屏幕上。此外，还提出了一种短声警告音。两秒钟后(t=2s)，一个指向左、右、下或上的箭头 提示(对应左手、右手、脚或舌头四个类别中的一个)出现，并在屏幕上停留1.25秒。这促使受试者执行他们想要的运动图像任务。 信号以250hz采样，在0.5 Hz到100hz之间进行带通滤波。

# %%
# 数据读取
import scipy.io as sio
import numpy as np



dataSetfile = r"D:\迅雷下载\BCI_MI_CSP_DNN\dataset_BCIcomp1.mat"
testLabelfile = r"D:\迅雷下载\BCI_MI_CSP_DNN\labels_data_set_iii.mat"
dataSet = sio.loadmat(dataSetfile)
testLabel = sio.loadmat(testLabelfile)


# print(dataSet['x_train'].shape) # (1152, 3, 140)  # 1152 = 128 * 9
# print(dataSet['x_test'].shape) # (1152, 3, 140)
# print(dataSet['y_train'].shape) # (140, 1)
# print(testLabel['y_test'].shape) # (140, 1)


# concat data
dataTrain = np.concatenate([dataSet['x_train'], dataSet['x_test']], axis=2)
dataLabel = np.concatenate([dataSet['y_train'], testLabel['y_test']])
print('data shape:', dataTrain.shape) # (1152, 3, 280)
print('dataLabel.shape:',dataLabel.shape) # (280, 1)
# Out:
# data shape: (1152, 3, 280)
# dataLabel.shape: (280, 1)

# %%
# 数据可视化
# %matplotlib inline
import matplotlib.pyplot as plt

plt.style.use('seaborn') # 设置背景样式
sampleRate = 128 # EEG 采样频率为128Hz

# numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None)
#在指定的间隔内返回均匀间隔的数字。

print(dataTrain.shape)# 1152     (1152, 3, 280)
t = np.linspace(0,dataTrain.shape[0]/sampleRate,dataTrain.shape[0])  
i = 1
C3 = dataTrain[:, 0, i]
C4 = dataTrain[:, 2, i]
plt.plot(t, C3, 'r', label='C3') 
plt.plot(t, C4, 'b', label='C4')
plt.xlabel('time /s')
plt.ylabel('amplitude') # 振幅
plt.legend(loc='upper right',fontsize='large',frameon=True,edgecolor='blue')
# Out:
# (1152, 3, 280)

# %% [markdown]
# ##  预处理
#
# 脑电信号的预处理主要是去除信号中的噪声，滤除与运动图像任务无关的频率成分。一些数字信号中含有低频噪声，影响了信号的分析。它需要预处理，以消除信号基线。通过消除数据的趋势，分析可以集中在数据的波动上。线性趋势通常表示系统的增加或减少。小波分析可以测量信号的非线性趋势，小波分析可以对信号进行多尺度分析。从低频系数可以看出信号的基线线，并从原始信号中减去基线
#
#
# 脑电图的ERD/ERS现象主要体现  在8-30Hz的频段，对原始信号进行贷通滤波，选择8-30频段
# 肌电信号具有较宽的频率范围，较大的幅值部分分布在频率大于30hz的区域;眼球运动信号集中在5Hz以下的低频区域，尤其是前额区域。
#
#
# 在本实验中，我们使用空间滤波器来最大化信噪比。
# common averagereference (CAR)过滤器强调大多数通道中的公共组件，并从指定的通道中删除这些组件，以增加不同通道之间的差异。
# 相反，如果某些组件出现在大多数通道中，但不在兴趣通道中，则会在兴趣通道上生成工件。
# 拉普拉斯方法的效果与CAR相似，但只使用邻域信道的一小部分。
#
#
# 拉普拉斯滤波：这种方法提取的是发生在第i个电极的局部活动，它使用第i个电极的信号减去四个正交的最近邻电极信号的平均值
# 共同平均参考（CAR）：用第i个电极的信号减去其他所有的电极信号的平均值，以增强第i个电极上的局部活动。
#
#
#
# 当受试者进行左手运动成像时，C3通道在8-12 Hz波段的功率幅值增大，即发生ERS现象，而C4通道在8-12 Hz波段的功率幅值减小，即发生ERD现象。

# %% [markdown]
# ### 滤波器设计
#
# 通过时域转换为频域，在频域信号中去除相应频域信号，最后在逆转换还原为时域型号

# %% [markdown]
# 滤波函数
# ```
# scipy.signal.filtfilt(b, a, x, axis=-1, padtype='odd', padlen=None, method='pad', irlen=None)
# ```
# 输入参数：
#
# b: 滤波器的分子系数向量
#
# a: 滤波器的分母系数向量
#
# x: 要过滤的数据数组。（array型）
#
# axis: 指定要过滤的数据数组x的轴
#
# padtype: 必须是“奇数”、“偶数”、“常数”或“无”。这决定了用于过滤器应用的填充信号的扩展类型。{‘odd', ‘even', ‘constant', None}
#
# padlen：在应用滤波器之前在轴两端延伸X的元素数目。此值必须小于要滤波元素个数- 1。（int型或None）
#
# method：确定处理信号边缘的方法。当method为“pad”时，填充信号；填充类型padtype和padlen决定，irlen被忽略。当method为“gust”时，使用古斯塔夫森方法，而忽略padtype和padlen。{“pad” ，“gust”}
#
# irlen：当method为“gust”时，irlen指定滤波器的脉冲响应的长度。如果irlen是None，则脉冲响应的任何部分都被忽略。对于长信号，指定irlen可以显著改善滤波器的性能。（int型或None）
#
# 输出参数：
#
# y:滤波后的数据数组

# %% [markdown]
# 滤波器构造函数
# ```
# scipy.signal.butter(N, Wn, btype='low', analog=False, output='ba')
# ```
# 输入参数：
#
# N:滤波器的阶数
#
# Wn：归一化截止频率。计算公式Wn=2*截止频率/采样频率。（注意：根据采样定理，采样频率要大于两倍的信号本身最大的频率，才能还原信号。截止频率一定小于信号本身最大的频率，所以Wn一定在0和1之间）。当构造带通滤波器或者带阻滤波器时，Wn为长度为2的列表。
#
# btype : 滤波器类型{‘lowpass', ‘highpass', ‘bandpass', ‘bandstop'},
#
# output : 输出类型{‘ba', ‘zpk', ‘sos'},
#
# 输出参数：
#
# b，a: IIR滤波器的分子（b）和分母（a）多项式系数向量。output='ba'
#
# z,p,k: IIR滤波器传递函数的零点、极点和系统增益. output= 'zpk'
#
# sos: IIR滤波器的二阶截面表示。output= 'sos'

# %% [markdown]
# 例子
# 采样频率为1000Hz,滤除10hz以下和400hz以上的频率成分
# 则wn1 = 2*10/1000=0.02,wn2=2*400/1000=0.8。Wn=[0.02, 0.8]
#
# ```
# from scipy import signal
# b, a = signal.butter(8, [0.02,0.8], 'bandpass')
# filtedData = signal.filtfilt(b, a, data)  #data为要过滤的信号
# ```

# %%
'''
fir filter
butter bandpass filter
bandpass [8 30]
mu and beta rhythm
'''
import scipy.signal as signal
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.signal import butter, lfilter 



def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = signal.filtfilt(b, a, data)    # 这个y的格式和data的格式一样
    return y

def butter_bandpass(lowcut, highcut, fs, order=5): # fs为采样频率
    nyq = 0.5 * fs 
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='bandpass') # 分子b，分母a
    return b, a

# %%
# test 滤波器

T  = 1
sampRat = 1000
t = np.linspace(0, T, sampRat, False)  
test1 = np.sin(2*np.pi*5*t) + np.sin(2*np.pi*10*t)++np.sin(2*np.pi*20*t)
fig, (ax1, ax2,ax3) = plt.subplots(3, 1, sharex=True)
ax1.plot(t, test1)
ax1.set_title('before')
ax1.axis([0, 1, -3, 3])

# 带通滤波器 
test2 = butter_bandpass_filter (test1,8,18,1000)
ax2.plot(t, test2)
ax2.set_title('after filter ')
ax2.axis([0, 1, -3, 3])


# 对比
test3 = np.sin(2*np.pi*10*t)
ax3.plot(t, test3)
ax3.axis([0, 1, -3, 3])
plt.tight_layout()
plt.show()


# 傅里叶变换
f = np.linspace(0, sampRat, T*sampRat, endpoint=False)
ff = np.fft.fft(test1)
ff = np.abs(ff)*2/T/sampRat
plt.figure()
plt.plot(f, ff)
plt.title('FFT before filter')
plt.show()

ff1 = np.fft.fft(test2)
ff1 = np.abs(ff1)*2/T/sampRat
plt.figure()
plt.plot(f, ff1)
plt.title('FFT after filter')
plt.show()

# %%
print(dataTrain.shape)
print(sampleRate)
dataTrain = butter_bandpass_filter(dataTrain,8,30,sampleRate)
print("滤波完成")
# Out:
# (1152, 3, 280)
# 128
# 滤波完成

# %% [markdown]
# ## 小波变换

# %%
# Wavelet transform generates time-frequency graph   小波变换生成时频图
# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt
import pywt


print(plt.style.available)
plt.style.use('classic')


wavlist = pywt.wavelist(kind='continuous') # 各种连续的小波已经被实现
print("Class of continuous wavelet functions：")
print(wavlist)


sampling_rate = 128 
t = np.arange(0,9.0,1.0/sampling_rate)
wavename = 'morl'    # "cmorB-C" where B is the bandwidth and C is the center frequency.其中B是带宽，C是中心频率。
# frequencies = pywt.scale2frequency('cmor1.5-0.5', [1, 2, 3, 4]) / (1/sampling_rate)
# print(frequencies)
totalscal = 64    # scale 
fc = pywt.central_frequency(wavename) #  central frequency
cparam = 2 * fc * totalscal
scales = cparam/np.arange(1,totalscal+1)
# C3 channel
[cwtmatr, frequencies] = pywt.cwt(dataTrain[:,0,3],scales,wavename,1.0/sampling_rate) # continuous wavelet transform
fig = plt.figure(1)
plt.contourf(t, frequencies, abs(cwtmatr))
plt.ylabel(u"freq(Hz)")
plt.xlabel(u"time(s)")
plt.colorbar()
# fig.savefig('C3.png')
fig = plt.figure(2)
# C4 channel
[cwtmatr, frequencies] = pywt.cwt(dataTrain[:,2,3],scales,wavename,1.0/sampling_rate) #连续小波变换
plt.contourf(t, frequencies, abs(cwtmatr))
plt.ylabel(u"freq(Hz)")
plt.xlabel(u"time(s)")
plt.colorbar()
# fig.savefig('C4.png')
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
# Class of continuous wavelet functions：
# ['cgau1', 'cgau2', 'cgau3', 'cgau4', 'cgau5', 'cgau6', 'cgau7', 'cgau8', 'cmor', 'fbsp', 'gaus1', 'gaus2', 'gaus3', 'gaus4', 'gaus5', 'gaus6', 'gaus7', 'gaus8', 'mexh', 'morl', 'shan']

# %%
'''
Wavelet transfrom 
Time-frequency diagram combination
select 3-6s EEG data every trial
'''
TimeStart = 3                     # start time
TimeEnd = 6                       # end time 
sampling_rate = 128 
samplePointStart=TimeStart*sampling_rate
samplePointEnd=TimeEnd*sampling_rate

# data capture 3-6s
dataTrainC3 = dataTrain[samplePointStart:samplePointEnd,0,:]
dataTrianC4 = dataTrain[samplePointStart:samplePointEnd,2,:]
sampling_rate = 128 

wavename = 'morl'    # "cmorB-C" where B is the bandwidth and C is the center frequency.
# frequencies = pywt.scale2frequency('cmor1.5-0.5', [1, 2, 3, 4]) / (1/sampling_rate)
# print(frequencies)
totalscal = 64    # scale 
fc = pywt.central_frequency(wavename) #  central frequency
cparam = 2 * fc * totalscal
scales = cparam/np.arange(1,totalscal+1)
t = np.arange(3,6.0,1.0/sampling_rate)


# wavelet transfrom 
for i in range(280):
    figureName = str(i)
    [cwtmatr3, frequencies3] = pywt.cwt(dataTrainC3[:,i],scales,wavename,1.0/sampling_rate) 
    [cwtmatr4, frequencies4] = pywt.cwt(dataTrianC4[:,i],scales,wavename,1.0/sampling_rate) 
    cwtmatr = np.concatenate([abs(cwtmatr3[7:30,:]), abs(cwtmatr4[7:30,:])],axis=0)   # the sequence is C3 then C4
    fig = plt.figure()
    plt.contourf(cwtmatr) # 用来绘制等高线的
    plt.xticks([])  # remove x
    plt.yticks([])  # remove y
    plt.axis('off') # remove axis
    fig.set_size_inches(800/100.0,600/100.0)#  set pixels width*height
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())
    plt.subplots_adjust(top=1,bottom=0,left=0,right=1,hspace =0, wspace =0) # 调整布局
    plt.margins(0,0)
    #plt.savefig(path)
    if dataLabel[i][0] == 1:
        filepath = r'D:\workspace\Jupyter Notebook\zx_CNN_wavelet_MI\wavelet_feature\morl\1\{}.jpg'.format(figureName)
    if dataLabel[i][0] == 2:
        filepath = r'D:\workspace\Jupyter Notebook\zx_CNN_wavelet_MI\wavelet_feature\morl\2\{}.jpg'.format(figureName)
    #print(filepath)  
    fig.savefig(filepath)
    fig.clear()
    #print('The {} sample wavelet transform is completed'.format(i))
    
print('wavelet transfrom completed')
plt.close(all)    

#plt.colorbar()
# Out:
# D:\Anaconda3\envs\learn\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# wavelet transfrom completed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-834aa0d3ab43> in <module>()
#      52
#      53 print('wavelet transfrom completed')
# ---> 54 plt.close(all)
#      55
#      56 #plt.colorbar()
#
# D:\Anaconda3\envs\learn\lib\site-packages\matplotlib\pyplot.py in close(fig)
#     830         _pylab_helpers.Gcf.destroy_fig(fig)
#     831     else:
# --> 832         raise TypeError("close() argument must be a Figure, an int, a string, "
#     833                         "or None, not '%s'")
#     834
#
# TypeError: close() argument must be a Figure, an int, a string, or None, not '%s'

# %% [markdown]
# # CNN模型
# 一个典型的CNN网络有以下几层:输入层、卷积层、池化层、完全连接层、输出层。卷积核提取输入的局部接受域特征，然后将该特征作为池化层的输入。
#
# CNN的抽象能力与需要学习的层数和参数正相关。
#
# 我们交替计算卷积层和池化层，使得特征图的大小减小，通道数量增加。到全连通层时，将之前得到的特征进行扁平化，最终通过前馈网络实现分类结果
#
# CNN中的经典模型更适合有足够数据的训练，在BCI中并不是适合。BCI数据集难以训练，更容易出现过拟合。针对小数据集，提出一种2层卷积网络。输入图像统一调整为64*64.内核大小也会相应的调整。本文采用了两种类型的核，一种是二维核一种是一维核。

# %%
# load feature dataset
import os
import numpy as np
def get_file(filename):
    ''' load time frequency diagram '''
    dataTrain = list()
    labelTrain = list()
    for label in os.listdir(filename):
        for pic in os.listdir(filename+label):
            dataTrain.append(filename+label+'/'+pic)  # shuffle data
            labelTrain.append(int(label))
    temp = np.array([dataTrain, labelTrain])  # （2,280）         
    temp = np.transpose(temp)   # 280*2
    np.random.shuffle(temp)  #洗牌
    image_list = temp[:,0]
    label_list = temp[:,1]
    label_list = [int(i) for i in label_list]  
    return image_list, label_list
pathname = r"D:/workspace/Jupyter Notebook/zx_CNN_wavelet_MI/wavelet_feature/morl/"
image_list, label_list = get_file(pathname) 

print(len(image_list),len(label_list))
print(image_list[10])
# Out:
# 280 280
# D:/workspace/Jupyter Notebook/zx_CNN_wavelet_MI/wavelet_feature/morl/2/118.jpg

# %%
# read figure Demo
import matplotlib.pyplot as plt
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
# read binary data
image_raw = tf.io.gfile.GFile(image_list[10],'rb').read()
# tf decode
img = tf.image.decode_jpeg(image_raw)  #Tensor  将JPEG编码图像解码为uint8张量.
 
with tf.compat.v1.Session() as sess:
   img_ = img.eval()  # 等价于sess.run(img)
   print(img_.shape)
 
plt.figure(1)
plt.imshow(img_)
plt.show()
# Out:
# (600, 800, 3)

# %%
"""
X_Train train data 280 samples
Y_Train train label
"""

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()


# read train data  figure-->tensor
# read_file 
# decode_jpeg
X = np.empty([280,64,64,3])
with tf.compat.v1.Session() as sess:
    for i in range(len(image_list)):
        # 读取图像文件
        image_raw_data = tf.io.gfile.GFile(image_list[i],'rb').read() 
        # 将图像文件解码为tensor
        image_data = tf.image.decode_jpeg(image_raw_data)
        # 改变张量的形状
        resized = tf.image.resize_images(image_data, [64,64],method=0)  
        #resized = tf.image.resize(image_data, [64,64],method=0)  
        resized = np.asarray(resized.eval(),dtype='uint8')      # asarray 生成数组 深拷贝不复制对象   .eval()等价于 sess.run(resized)
        X[i,:,:,:]=resized  

# train data
X_Train = X[:,:,:,:]
Y = np.subtract(np.array(label_list), 1)
Y = Y.reshape([280,1])
V = tf.one_hot(Y, depth=2,axis=1,dtype=tf.float32) # 返回一个one_hot张量
session = tf.Session()
Y_Train = session.run(V)
session.close()
# resize
Y_Train = Y_Train.reshape([280,2])
#  normalization
X_Train = X_Train/255.
print ("X_Train shape: " + str(X_Train.shape))
print ("Y_Train shape: " + str(Y_Train.shape))
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\learn\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# X_Train shape: (280, 64, 64, 3)
# Y_Train shape: (280, 2)

# %%
# Keras 序贯模型  deep learning API

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, Conv1D, BatchNormalization, MaxPool2D
from tensorflow.keras.optimizers import Adam            # 优化器
# import keras 



input_shape = X_Train.shape[1:]
# print(input_shape)  # (64, 64, 3)
num_classes = 2

model = Sequential()

model.add(Conv2D(16, (4,4), padding = 'same', input_shape = input_shape, kernel_initializer = 'he_normal', name = 'conv2d_1'))
model.add(Activation('relu',name = 'activation_1'))
model.add(MaxPool2D(pool_size=(8,8),name = 'maxpool2d_1'))
model.add(Dropout(0.25,name = 'dropout_1'))

model.add(Conv2D(32, (4,4), padding = 'same',kernel_initializer = 'he_normal', name = 'conv2d_2'))
model.add(Activation('relu',name = 'activation_2'))
model.add(MaxPool2D(pool_size=(2,2),name = 'maxpool2d_2'))
model.add(Dropout(0.25,name = 'dropout_2'))

model.add(Flatten(name = 'flatten_1'))
model.add(Dense(240,kernel_initializer='he_normal',name='dense_1'))
model.add(Activation('relu',name='activation_3'))
model.add(Dropout(0.5,name = 'dropout_3'))
model.add(Dense(num_classes, kernel_initializer='he_normal',name='dense_2'))
model.add(Activation('softmax',name='activation_4'))
model.summary()

# 优化方法
opt = keras.optimizers.Adam(lr=0.0003, decay = 1e-6)
# 编译模型
model.compile(loss = 'categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\learn\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1635: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 16)        784
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 64, 16)        0
# _________________________________________________________________
# maxpool2d_1 (MaxPooling2D)   (None, 8, 8, 16)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 32)          8224
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 8, 32)          0
# _________________________________________________________________
# maxpool2d_2 (MaxPooling2D)   (None, 4, 4, 32)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 240)               123120
# _________________________________________________________________
# activation_3 (Activation)    (None, 240)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 240)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 482
# _________________________________________________________________
# activation_4 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 132,610
# Trainable params: 132,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train model
epochs = 300
history = model.fit(X_Train, Y_Train, shuffle=True, batch_size=8, epochs=epochs, verbose=1, validation_split=0.3)
# Out:
# Train on 196 samples, validate on 84 samples
# Epoch 1/300
# 196/196 [==============================] - 1s 4ms/sample - loss: 1.9187 - acc: 0.5204 - val_loss: 0.6716 - val_acc: 0.6190
# Epoch 2/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 1.3702 - acc: 0.4898 - val_loss: 0.7399 - val_acc: 0.4762
# Epoch 3/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 1.1189 - acc: 0.5510 - val_loss: 0.6590 - val_acc: 0.6190
# Epoch 4/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 1.0102 - acc: 0.5153 - val_loss: 0.6583 - val_acc: 0.6190
# Epoch 5/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.9211 - acc: 0.5357 - val_loss: 0.6662 - val_acc: 0.6190
# Epoch 6/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.8262 - acc: 0.5408 - val_loss: 0.6702 - val_acc: 0.6310
# Epoch 7/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.7988 - acc: 0.5255 - val_loss: 0.6829 - val_acc: 0.5000
# Epoch 8/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.8094 - acc: 0.5051 - val_loss: 0.6628 - val_acc: 0.6310
# Epoch 9/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.7419 - acc: 0.5510 - val_loss: 0.6688 - val_acc: 0.6190
# Epoch 10/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.7842 - acc: 0.5408 - val_loss: 0.6675 - val_acc: 0.6429
# Epoch 11/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.8219 - acc: 0.5204 - val_loss: 0.6790 - val_acc: 0.4881
# Epoch 12/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.7220 - acc: 0.5408 - val_loss: 0.6806 - val_acc: 0.5357
# Epoch 13/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.7557 - acc: 0.5255 - val_loss: 0.6868 - val_acc: 0.5000
# Epoch 14/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.7051 - acc: 0.5204 - val_loss: 0.6798 - val_acc: 0.5119
# Epoch 15/300
# 196/196 [==============================] - ETA: 0s - loss: 0.7316 - acc: 0.511 - 0s 2ms/sample - loss: 0.7251 - acc: 0.5204 - val_loss: 0.6958 - val_acc: 0.5000
# Epoch 16/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.7003 - acc: 0.5663 - val_loss: 0.6860 - val_acc: 0.5000
# Epoch 17/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.7074 - acc: 0.5357 - val_loss: 0.6891 - val_acc: 0.5000
# Epoch 18/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6743 - acc: 0.5765 - val_loss: 0.6907 - val_acc: 0.5238
# Epoch 19/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.7230 - acc: 0.5459 - val_loss: 0.6915 - val_acc: 0.4881
# Epoch 20/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6979 - acc: 0.5561 - val_loss: 0.6992 - val_acc: 0.4643
# Epoch 21/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6321 - acc: 0.6173 - val_loss: 0.6963 - val_acc: 0.4643
# Epoch 22/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6885 - acc: 0.5918 - val_loss: 0.6973 - val_acc: 0.4643
# Epoch 23/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6651 - acc: 0.5816 - val_loss: 0.6965 - val_acc: 0.4524
# Epoch 24/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6733 - acc: 0.5816 - val_loss: 0.6900 - val_acc: 0.5000
# Epoch 25/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6674 - acc: 0.6173 - val_loss: 0.6880 - val_acc: 0.5476
# Epoch 26/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6773 - acc: 0.5612 - val_loss: 0.6898 - val_acc: 0.5595
# Epoch 27/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6647 - acc: 0.6224 - val_loss: 0.6851 - val_acc: 0.5357
# Epoch 28/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6665 - acc: 0.5867 - val_loss: 0.6898 - val_acc: 0.5357
# Epoch 29/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6730 - acc: 0.6020 - val_loss: 0.6879 - val_acc: 0.5595
# Epoch 30/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6785 - acc: 0.5918 - val_loss: 0.6874 - val_acc: 0.5476
# Epoch 31/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6562 - acc: 0.6327 - val_loss: 0.6866 - val_acc: 0.5595
# Epoch 32/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6520 - acc: 0.6378 - val_loss: 0.6849 - val_acc: 0.5238
# Epoch 33/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6565 - acc: 0.6276 - val_loss: 0.6892 - val_acc: 0.5357
# Epoch 34/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6416 - acc: 0.6224 - val_loss: 0.6897 - val_acc: 0.5476
# Epoch 35/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6335 - acc: 0.6582 - val_loss: 0.6860 - val_acc: 0.5357
# Epoch 36/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6649 - acc: 0.5612 - val_loss: 0.7013 - val_acc: 0.5119
# Epoch 37/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6313 - acc: 0.6939 - val_loss: 0.6867 - val_acc: 0.5238
# Epoch 38/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6536 - acc: 0.6071 - val_loss: 0.6872 - val_acc: 0.5714
# Epoch 39/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6637 - acc: 0.6071 - val_loss: 0.6872 - val_acc: 0.5357
# Epoch 40/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6576 - acc: 0.5969 - val_loss: 0.6880 - val_acc: 0.5476
# Epoch 41/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6278 - acc: 0.6531 - val_loss: 0.6854 - val_acc: 0.5714
# Epoch 42/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6279 - acc: 0.6480 - val_loss: 0.6844 - val_acc: 0.5595
# Epoch 43/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6610 - acc: 0.6071 - val_loss: 0.6868 - val_acc: 0.5714
# Epoch 44/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6557 - acc: 0.5714 - val_loss: 0.6804 - val_acc: 0.5714
# Epoch 45/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6589 - acc: 0.6020 - val_loss: 0.6901 - val_acc: 0.5357
# Epoch 46/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6516 - acc: 0.6071 - val_loss: 0.6856 - val_acc: 0.5714
# Epoch 47/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6163 - acc: 0.6327 - val_loss: 0.6896 - val_acc: 0.5238
# Epoch 48/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6102 - acc: 0.6684 - val_loss: 0.6959 - val_acc: 0.5238
# Epoch 49/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6475 - acc: 0.6378 - val_loss: 0.6911 - val_acc: 0.5357
# Epoch 50/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5951 - acc: 0.6837 - val_loss: 0.6983 - val_acc: 0.5357
# Epoch 51/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6408 - acc: 0.6378 - val_loss: 0.6924 - val_acc: 0.5238
# Epoch 52/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6223 - acc: 0.6684 - val_loss: 0.6882 - val_acc: 0.5476
# Epoch 53/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6229 - acc: 0.6531 - val_loss: 0.6857 - val_acc: 0.5595
# Epoch 54/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6211 - acc: 0.6327 - val_loss: 0.6894 - val_acc: 0.5476
# Epoch 55/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5899 - acc: 0.6888 - val_loss: 0.6998 - val_acc: 0.5595
# Epoch 56/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5966 - acc: 0.6735 - val_loss: 0.7167 - val_acc: 0.4762
# Epoch 57/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6164 - acc: 0.6633 - val_loss: 0.6929 - val_acc: 0.5357
# Epoch 58/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6229 - acc: 0.6582 - val_loss: 0.6992 - val_acc: 0.5595
# Epoch 59/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6354 - acc: 0.6480 - val_loss: 0.6948 - val_acc: 0.5595
# Epoch 60/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6159 - acc: 0.6480 - val_loss: 0.6857 - val_acc: 0.5476
# Epoch 61/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5930 - acc: 0.6531 - val_loss: 0.6920 - val_acc: 0.5238
# Epoch 62/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6264 - acc: 0.6276 - val_loss: 0.6878 - val_acc: 0.5119
# Epoch 63/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6004 - acc: 0.6684 - val_loss: 0.6864 - val_acc: 0.5476
# Epoch 64/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6580 - acc: 0.6327 - val_loss: 0.6827 - val_acc: 0.5357
# Epoch 65/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6141 - acc: 0.6786 - val_loss: 0.6918 - val_acc: 0.5595
# Epoch 66/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6144 - acc: 0.6837 - val_loss: 0.6990 - val_acc: 0.5595
# Epoch 67/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6163 - acc: 0.6633 - val_loss: 0.6914 - val_acc: 0.5238
# Epoch 68/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5961 - acc: 0.6582 - val_loss: 0.7105 - val_acc: 0.4881
# Epoch 69/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6025 - acc: 0.6837 - val_loss: 0.6920 - val_acc: 0.5238
# Epoch 70/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5892 - acc: 0.6684 - val_loss: 0.6906 - val_acc: 0.5119
# Epoch 71/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6106 - acc: 0.6480 - val_loss: 0.6839 - val_acc: 0.5476
# Epoch 72/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6101 - acc: 0.6480 - val_loss: 0.7006 - val_acc: 0.5238
# Epoch 73/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5888 - acc: 0.7041 - val_loss: 0.6884 - val_acc: 0.5357
# Epoch 74/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5775 - acc: 0.6684 - val_loss: 0.6938 - val_acc: 0.5714
# Epoch 75/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5963 - acc: 0.6735 - val_loss: 0.6913 - val_acc: 0.5714
# Epoch 76/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6063 - acc: 0.6939 - val_loss: 0.6846 - val_acc: 0.5595
# Epoch 77/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5919 - acc: 0.6480 - val_loss: 0.7103 - val_acc: 0.5119
# Epoch 78/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5719 - acc: 0.6786 - val_loss: 0.6968 - val_acc: 0.5476
# Epoch 79/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5543 - acc: 0.7194 - val_loss: 0.6967 - val_acc: 0.5595
# Epoch 80/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5821 - acc: 0.7143 - val_loss: 0.7049 - val_acc: 0.5714
# Epoch 81/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5846 - acc: 0.6939 - val_loss: 0.7021 - val_acc: 0.5595
# Epoch 82/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5981 - acc: 0.6633 - val_loss: 0.7043 - val_acc: 0.5476
# Epoch 83/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5695 - acc: 0.6837 - val_loss: 0.7010 - val_acc: 0.5595
# Epoch 84/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5947 - acc: 0.7143 - val_loss: 0.6896 - val_acc: 0.5238
# Epoch 85/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6155 - acc: 0.6735 - val_loss: 0.6872 - val_acc: 0.5476
# Epoch 86/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5647 - acc: 0.7092 - val_loss: 0.6969 - val_acc: 0.5595
# Epoch 87/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5375 - acc: 0.7245 - val_loss: 0.6911 - val_acc: 0.5714
# Epoch 88/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5786 - acc: 0.7041 - val_loss: 0.6978 - val_acc: 0.5595
# Epoch 89/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5432 - acc: 0.7143 - val_loss: 0.7110 - val_acc: 0.5357
# Epoch 90/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5779 - acc: 0.6888 - val_loss: 0.6804 - val_acc: 0.5476
# Epoch 91/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5497 - acc: 0.7041 - val_loss: 0.6881 - val_acc: 0.5476
# Epoch 92/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.6007 - acc: 0.6224 - val_loss: 0.6963 - val_acc: 0.5476
# Epoch 93/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5614 - acc: 0.7143 - val_loss: 0.6917 - val_acc: 0.5595
# Epoch 94/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5610 - acc: 0.7092 - val_loss: 0.7019 - val_acc: 0.5357
# Epoch 95/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5705 - acc: 0.7041 - val_loss: 0.6962 - val_acc: 0.5595
# Epoch 96/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5384 - acc: 0.6837 - val_loss: 0.7089 - val_acc: 0.5357
# Epoch 97/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5765 - acc: 0.6684 - val_loss: 0.7065 - val_acc: 0.5476
# Epoch 98/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5466 - acc: 0.7143 - val_loss: 0.7211 - val_acc: 0.5238
# Epoch 99/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5662 - acc: 0.6735 - val_loss: 0.6919 - val_acc: 0.5595
# Epoch 100/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5674 - acc: 0.6939 - val_loss: 0.7011 - val_acc: 0.5595
# Epoch 101/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5694 - acc: 0.7092 - val_loss: 0.7052 - val_acc: 0.5476
# Epoch 102/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5409 - acc: 0.7296 - val_loss: 0.6985 - val_acc: 0.5357
# Epoch 103/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5221 - acc: 0.7500 - val_loss: 0.7008 - val_acc: 0.5357
# Epoch 104/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4944 - acc: 0.7653 - val_loss: 0.7306 - val_acc: 0.5476
# Epoch 105/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5048 - acc: 0.7602 - val_loss: 0.7147 - val_acc: 0.5595
# Epoch 106/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5552 - acc: 0.6990 - val_loss: 0.7305 - val_acc: 0.5714
# Epoch 107/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5466 - acc: 0.6939 - val_loss: 0.7246 - val_acc: 0.5357
# Epoch 108/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5177 - acc: 0.7449 - val_loss: 0.6998 - val_acc: 0.5595
# Epoch 109/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5659 - acc: 0.7194 - val_loss: 0.7342 - val_acc: 0.5476
# Epoch 110/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5401 - acc: 0.7143 - val_loss: 0.7081 - val_acc: 0.5952
# Epoch 111/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5320 - acc: 0.7653 - val_loss: 0.7211 - val_acc: 0.5595
# Epoch 112/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5278 - acc: 0.7500 - val_loss: 0.7381 - val_acc: 0.5357
# Epoch 113/300
# 196/196 [==============================] - 0s 1ms/sample - loss: 0.5272 - acc: 0.7245 - val_loss: 0.7106 - val_acc: 0.5714
# Epoch 114/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5309 - acc: 0.7143 - val_loss: 0.7000 - val_acc: 0.5476
# Epoch 115/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4895 - acc: 0.7806 - val_loss: 0.7366 - val_acc: 0.5833
# Epoch 116/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5297 - acc: 0.7602 - val_loss: 0.7177 - val_acc: 0.5238
# Epoch 117/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5135 - acc: 0.7449 - val_loss: 0.7229 - val_acc: 0.5119
# Epoch 118/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5087 - acc: 0.7500 - val_loss: 0.7249 - val_acc: 0.5357
# Epoch 119/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5265 - acc: 0.7602 - val_loss: 0.7656 - val_acc: 0.5119
# Epoch 120/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5321 - acc: 0.7398 - val_loss: 0.7391 - val_acc: 0.5476
# Epoch 121/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4976 - acc: 0.7551 - val_loss: 0.7657 - val_acc: 0.5476
# Epoch 122/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5208 - acc: 0.7245 - val_loss: 0.7488 - val_acc: 0.5357
# Epoch 123/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4953 - acc: 0.7347 - val_loss: 0.7450 - val_acc: 0.5238
# Epoch 124/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4932 - acc: 0.7908 - val_loss: 0.7307 - val_acc: 0.5595
# Epoch 125/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4684 - acc: 0.7755 - val_loss: 0.7522 - val_acc: 0.5238
# Epoch 126/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5031 - acc: 0.7602 - val_loss: 0.7535 - val_acc: 0.5238
# Epoch 127/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5367 - acc: 0.7245 - val_loss: 0.7149 - val_acc: 0.5476
# Epoch 128/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4806 - acc: 0.7857 - val_loss: 0.7413 - val_acc: 0.5714
# Epoch 129/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4952 - acc: 0.7500 - val_loss: 0.7326 - val_acc: 0.5833
# Epoch 130/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5003 - acc: 0.7398 - val_loss: 0.7278 - val_acc: 0.5595
# Epoch 131/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4856 - acc: 0.7959 - val_loss: 0.7351 - val_acc: 0.5357
# Epoch 132/300
# 196/196 [==============================] - 0s 1ms/sample - loss: 0.5338 - acc: 0.7041 - val_loss: 0.7458 - val_acc: 0.5238
# Epoch 133/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4850 - acc: 0.7602 - val_loss: 0.7554 - val_acc: 0.5238
# Epoch 134/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4877 - acc: 0.7500 - val_loss: 0.7649 - val_acc: 0.5119
# Epoch 135/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4690 - acc: 0.7755 - val_loss: 0.7351 - val_acc: 0.5476
# Epoch 136/300
# 196/196 [==============================] - 0s 1ms/sample - loss: 0.4756 - acc: 0.7653 - val_loss: 0.7467 - val_acc: 0.5595
# Epoch 137/300
# 196/196 [==============================] - 0s 1ms/sample - loss: 0.4432 - acc: 0.7806 - val_loss: 0.7602 - val_acc: 0.5595
# Epoch 138/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4879 - acc: 0.7296 - val_loss: 0.7347 - val_acc: 0.5595
# Epoch 139/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4798 - acc: 0.7500 - val_loss: 0.7477 - val_acc: 0.5476
# Epoch 140/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4624 - acc: 0.7908 - val_loss: 0.7747 - val_acc: 0.5119
# Epoch 141/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4767 - acc: 0.7857 - val_loss: 0.7490 - val_acc: 0.5357
# Epoch 142/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4528 - acc: 0.7959 - val_loss: 0.7995 - val_acc: 0.4881
# Epoch 143/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4748 - acc: 0.7653 - val_loss: 0.7839 - val_acc: 0.5000
# Epoch 144/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4320 - acc: 0.8163 - val_loss: 0.7984 - val_acc: 0.5000
# Epoch 145/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4377 - acc: 0.8010 - val_loss: 0.7560 - val_acc: 0.4881
# Epoch 146/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4772 - acc: 0.7296 - val_loss: 0.7620 - val_acc: 0.5238
# Epoch 147/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.5175 - acc: 0.7449 - val_loss: 0.7705 - val_acc: 0.5000
# Epoch 148/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4346 - acc: 0.7806 - val_loss: 0.7461 - val_acc: 0.5238
# Epoch 149/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3838 - acc: 0.8265 - val_loss: 0.8312 - val_acc: 0.5000
# Epoch 150/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4541 - acc: 0.7653 - val_loss: 0.7914 - val_acc: 0.5119
# Epoch 151/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4111 - acc: 0.8010 - val_loss: 0.8249 - val_acc: 0.5119
# Epoch 152/300
# 196/196 [==============================] - 1s 3ms/sample - loss: 0.4161 - acc: 0.8061 - val_loss: 0.8232 - val_acc: 0.5119
# Epoch 153/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3773 - acc: 0.8520 - val_loss: 0.7578 - val_acc: 0.5714
# Epoch 154/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3761 - acc: 0.8061 - val_loss: 0.8249 - val_acc: 0.5238
# Epoch 155/300
# 196/196 [==============================] - 1s 3ms/sample - loss: 0.3780 - acc: 0.7959 - val_loss: 0.7840 - val_acc: 0.5714
# Epoch 156/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4551 - acc: 0.8010 - val_loss: 0.7885 - val_acc: 0.5238
# Epoch 157/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4065 - acc: 0.7959 - val_loss: 0.7840 - val_acc: 0.5357
# Epoch 158/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4344 - acc: 0.8010 - val_loss: 0.8019 - val_acc: 0.5238
# Epoch 159/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3847 - acc: 0.8163 - val_loss: 0.8430 - val_acc: 0.5119
# Epoch 160/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3423 - acc: 0.8469 - val_loss: 0.8633 - val_acc: 0.4881
# Epoch 161/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4168 - acc: 0.7959 - val_loss: 0.8335 - val_acc: 0.5595
# Epoch 162/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4162 - acc: 0.7755 - val_loss: 0.8289 - val_acc: 0.5238
# Epoch 163/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3816 - acc: 0.8571 - val_loss: 0.7977 - val_acc: 0.5595
# Epoch 164/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4156 - acc: 0.8061 - val_loss: 0.7954 - val_acc: 0.5476
# Epoch 165/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4364 - acc: 0.8061 - val_loss: 0.7888 - val_acc: 0.5595
# Epoch 166/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3916 - acc: 0.8112 - val_loss: 0.8664 - val_acc: 0.4762
# Epoch 167/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3750 - acc: 0.8214 - val_loss: 0.8043 - val_acc: 0.5476
# Epoch 168/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3991 - acc: 0.8265 - val_loss: 0.8574 - val_acc: 0.4643
# Epoch 169/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3793 - acc: 0.7908 - val_loss: 0.7997 - val_acc: 0.5833
# Epoch 170/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3903 - acc: 0.8316 - val_loss: 0.8664 - val_acc: 0.5119
# Epoch 171/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3779 - acc: 0.8418 - val_loss: 0.8325 - val_acc: 0.5357
# Epoch 172/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3626 - acc: 0.8520 - val_loss: 0.8879 - val_acc: 0.5119
# Epoch 173/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3563 - acc: 0.8418 - val_loss: 0.8585 - val_acc: 0.5357
# Epoch 174/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.4239 - acc: 0.7704 - val_loss: 0.8203 - val_acc: 0.5238
# Epoch 175/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3964 - acc: 0.8112 - val_loss: 0.8529 - val_acc: 0.5238
# Epoch 176/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3897 - acc: 0.8061 - val_loss: 0.8321 - val_acc: 0.4881
# Epoch 177/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3296 - acc: 0.8418 - val_loss: 0.8639 - val_acc: 0.5000
# Epoch 178/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3117 - acc: 0.8827 - val_loss: 0.9143 - val_acc: 0.4643
# Epoch 179/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3734 - acc: 0.8112 - val_loss: 0.8358 - val_acc: 0.5476
# Epoch 180/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3644 - acc: 0.8316 - val_loss: 0.8756 - val_acc: 0.5119
# Epoch 181/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3200 - acc: 0.8571 - val_loss: 0.9182 - val_acc: 0.4643
# Epoch 182/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3592 - acc: 0.8061 - val_loss: 0.8796 - val_acc: 0.5357
# Epoch 183/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3198 - acc: 0.8622 - val_loss: 0.9054 - val_acc: 0.5476
# Epoch 184/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3440 - acc: 0.8520 - val_loss: 0.8638 - val_acc: 0.5595
# Epoch 185/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3270 - acc: 0.8367 - val_loss: 0.8623 - val_acc: 0.5357
# Epoch 186/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3658 - acc: 0.8265 - val_loss: 0.8846 - val_acc: 0.5238
# Epoch 187/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3384 - acc: 0.8367 - val_loss: 0.8488 - val_acc: 0.5357
# Epoch 188/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2776 - acc: 0.8980 - val_loss: 0.9314 - val_acc: 0.5119
# Epoch 189/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3058 - acc: 0.8724 - val_loss: 0.9580 - val_acc: 0.5119
# Epoch 190/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2636 - acc: 0.8878 - val_loss: 0.9547 - val_acc: 0.5119
# Epoch 191/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3402 - acc: 0.8418 - val_loss: 0.9382 - val_acc: 0.5119
# Epoch 192/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3445 - acc: 0.8469 - val_loss: 0.9139 - val_acc: 0.5119
# Epoch 193/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3204 - acc: 0.8418 - val_loss: 0.9093 - val_acc: 0.4881
# Epoch 194/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3468 - acc: 0.8469 - val_loss: 0.9737 - val_acc: 0.4643
# Epoch 195/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2796 - acc: 0.8980 - val_loss: 0.9441 - val_acc: 0.5119
# Epoch 196/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2460 - acc: 0.9031 - val_loss: 0.9026 - val_acc: 0.5595
# Epoch 197/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2997 - acc: 0.8673 - val_loss: 1.0363 - val_acc: 0.4762
# Epoch 198/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3091 - acc: 0.8520 - val_loss: 0.8935 - val_acc: 0.5238
# Epoch 199/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3070 - acc: 0.8776 - val_loss: 0.9724 - val_acc: 0.5000
# Epoch 200/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3107 - acc: 0.8878 - val_loss: 0.9580 - val_acc: 0.5238
# Epoch 201/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2668 - acc: 0.8827 - val_loss: 0.9959 - val_acc: 0.5238
# Epoch 202/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2465 - acc: 0.9235 - val_loss: 0.9709 - val_acc: 0.5357
# Epoch 203/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2911 - acc: 0.8929 - val_loss: 0.9603 - val_acc: 0.5238
# Epoch 204/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2687 - acc: 0.8980 - val_loss: 1.0366 - val_acc: 0.4762
# Epoch 205/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2613 - acc: 0.9235 - val_loss: 0.9644 - val_acc: 0.5000
# Epoch 206/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2841 - acc: 0.8776 - val_loss: 0.9816 - val_acc: 0.5000
# Epoch 207/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2389 - acc: 0.9184 - val_loss: 0.9462 - val_acc: 0.5476
# Epoch 208/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.3210 - acc: 0.8622 - val_loss: 0.9772 - val_acc: 0.5000
# Epoch 209/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2570 - acc: 0.8878 - val_loss: 0.9615 - val_acc: 0.5238
# Epoch 210/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2523 - acc: 0.8878 - val_loss: 0.9959 - val_acc: 0.5119
# Epoch 211/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2241 - acc: 0.9184 - val_loss: 1.0166 - val_acc: 0.4881
# Epoch 212/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2191 - acc: 0.9235 - val_loss: 1.0096 - val_acc: 0.5357
# Epoch 213/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2653 - acc: 0.9184 - val_loss: 1.0480 - val_acc: 0.5000
# Epoch 214/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2843 - acc: 0.8827 - val_loss: 0.9995 - val_acc: 0.5238
# Epoch 215/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2623 - acc: 0.8929 - val_loss: 1.0240 - val_acc: 0.5119
# Epoch 216/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2161 - acc: 0.9184 - val_loss: 0.9593 - val_acc: 0.5357
# Epoch 217/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2327 - acc: 0.9133 - val_loss: 1.0325 - val_acc: 0.5000
# Epoch 218/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2266 - acc: 0.9133 - val_loss: 1.0248 - val_acc: 0.5000
# Epoch 219/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2065 - acc: 0.9490 - val_loss: 0.9896 - val_acc: 0.5119
# Epoch 220/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2571 - acc: 0.9031 - val_loss: 1.0490 - val_acc: 0.4881
# Epoch 221/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2111 - acc: 0.9286 - val_loss: 1.0373 - val_acc: 0.5000
# Epoch 222/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2333 - acc: 0.9031 - val_loss: 1.0137 - val_acc: 0.4881
# Epoch 223/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2051 - acc: 0.9133 - val_loss: 1.0048 - val_acc: 0.5000
# Epoch 224/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2482 - acc: 0.9184 - val_loss: 1.0284 - val_acc: 0.5000
# Epoch 225/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2466 - acc: 0.8827 - val_loss: 1.0358 - val_acc: 0.5000
# Epoch 226/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2534 - acc: 0.9031 - val_loss: 1.0111 - val_acc: 0.5119
# Epoch 227/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1790 - acc: 0.9235 - val_loss: 1.0532 - val_acc: 0.5000
# Epoch 228/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1825 - acc: 0.9337 - val_loss: 1.0879 - val_acc: 0.4881
# Epoch 229/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2199 - acc: 0.9235 - val_loss: 1.0020 - val_acc: 0.5357
# Epoch 230/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2283 - acc: 0.9082 - val_loss: 1.0053 - val_acc: 0.5238
# Epoch 231/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2262 - acc: 0.9184 - val_loss: 1.1524 - val_acc: 0.4643
# Epoch 232/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2516 - acc: 0.8929 - val_loss: 1.0518 - val_acc: 0.5000
# Epoch 233/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2293 - acc: 0.9031 - val_loss: 1.0560 - val_acc: 0.5238
# Epoch 234/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1684 - acc: 0.9694 - val_loss: 1.0925 - val_acc: 0.4881
# Epoch 235/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1990 - acc: 0.9082 - val_loss: 1.0594 - val_acc: 0.5238
# Epoch 236/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1917 - acc: 0.9286 - val_loss: 1.0986 - val_acc: 0.5119
# Epoch 237/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1542 - acc: 0.9490 - val_loss: 1.1297 - val_acc: 0.5000
# Epoch 238/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1975 - acc: 0.9337 - val_loss: 1.1363 - val_acc: 0.4881
# Epoch 239/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1906 - acc: 0.9184 - val_loss: 1.1527 - val_acc: 0.4881
# Epoch 240/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2120 - acc: 0.9235 - val_loss: 1.1254 - val_acc: 0.5000
# Epoch 241/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1871 - acc: 0.9286 - val_loss: 1.1734 - val_acc: 0.4881
# Epoch 242/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1855 - acc: 0.9184 - val_loss: 1.2211 - val_acc: 0.5119
# Epoch 243/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1968 - acc: 0.8980 - val_loss: 1.1172 - val_acc: 0.5238
# Epoch 244/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2108 - acc: 0.9031 - val_loss: 1.3493 - val_acc: 0.4762
# Epoch 245/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2110 - acc: 0.9031 - val_loss: 1.1076 - val_acc: 0.4643
# Epoch 246/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1856 - acc: 0.9388 - val_loss: 1.1939 - val_acc: 0.4762
# Epoch 247/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2279 - acc: 0.9031 - val_loss: 1.0416 - val_acc: 0.4881
# Epoch 248/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2174 - acc: 0.9082 - val_loss: 1.0856 - val_acc: 0.4762
# Epoch 249/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1443 - acc: 0.9388 - val_loss: 1.1928 - val_acc: 0.4762
# Epoch 250/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1800 - acc: 0.9286 - val_loss: 1.1282 - val_acc: 0.4881
# Epoch 251/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1510 - acc: 0.9490 - val_loss: 1.1794 - val_acc: 0.4881
# Epoch 252/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1654 - acc: 0.9286 - val_loss: 1.1381 - val_acc: 0.4881
# Epoch 253/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1438 - acc: 0.9541 - val_loss: 1.2099 - val_acc: 0.4881
# Epoch 254/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1524 - acc: 0.9541 - val_loss: 1.1464 - val_acc: 0.4762
# Epoch 255/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1499 - acc: 0.9439 - val_loss: 1.2358 - val_acc: 0.5000
# Epoch 256/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1654 - acc: 0.9592 - val_loss: 1.1714 - val_acc: 0.5000
# Epoch 257/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1673 - acc: 0.9388 - val_loss: 1.1441 - val_acc: 0.5119
# Epoch 258/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1858 - acc: 0.9286 - val_loss: 1.2055 - val_acc: 0.5000
# Epoch 259/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1517 - acc: 0.9490 - val_loss: 1.1445 - val_acc: 0.5000
# Epoch 260/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1700 - acc: 0.9337 - val_loss: 1.2608 - val_acc: 0.4643
# Epoch 261/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.2025 - acc: 0.9337 - val_loss: 1.1135 - val_acc: 0.5119
# Epoch 262/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1770 - acc: 0.9388 - val_loss: 1.2116 - val_acc: 0.4762
# Epoch 263/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1717 - acc: 0.9286 - val_loss: 1.1241 - val_acc: 0.5238
# Epoch 264/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1519 - acc: 0.9490 - val_loss: 1.0699 - val_acc: 0.5238
# Epoch 265/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1194 - acc: 0.9643 - val_loss: 1.2059 - val_acc: 0.5000
# Epoch 266/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1568 - acc: 0.9388 - val_loss: 1.1356 - val_acc: 0.5119
# Epoch 267/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1697 - acc: 0.9439 - val_loss: 1.1400 - val_acc: 0.5119
# Epoch 268/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1122 - acc: 0.9796 - val_loss: 1.1948 - val_acc: 0.5238
# Epoch 269/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1391 - acc: 0.9490 - val_loss: 1.1800 - val_acc: 0.4762
# Epoch 270/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1390 - acc: 0.9439 - val_loss: 1.1463 - val_acc: 0.5357
# Epoch 271/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1279 - acc: 0.9592 - val_loss: 1.2194 - val_acc: 0.4881
# Epoch 272/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1196 - acc: 0.9694 - val_loss: 1.1855 - val_acc: 0.5119
# Epoch 273/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.0935 - acc: 0.9592 - val_loss: 1.3197 - val_acc: 0.4762
# Epoch 274/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1435 - acc: 0.9643 - val_loss: 1.4875 - val_acc: 0.5000
# Epoch 275/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1558 - acc: 0.9490 - val_loss: 1.2210 - val_acc: 0.4881
# Epoch 276/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1437 - acc: 0.9439 - val_loss: 1.2874 - val_acc: 0.5119
# Epoch 277/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1446 - acc: 0.9490 - val_loss: 1.2598 - val_acc: 0.5000
# Epoch 278/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1480 - acc: 0.9592 - val_loss: 1.2975 - val_acc: 0.4881
# Epoch 279/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.0899 - acc: 0.9745 - val_loss: 1.2912 - val_acc: 0.5119
# Epoch 280/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1391 - acc: 0.9592 - val_loss: 1.2522 - val_acc: 0.5000
# Epoch 281/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1045 - acc: 0.9796 - val_loss: 1.3229 - val_acc: 0.5000
# Epoch 282/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1484 - acc: 0.9439 - val_loss: 1.2570 - val_acc: 0.4881
# Epoch 283/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1776 - acc: 0.9235 - val_loss: 1.1977 - val_acc: 0.5119
# Epoch 284/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1377 - acc: 0.9643 - val_loss: 1.2048 - val_acc: 0.5119
# Epoch 285/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1324 - acc: 0.9592 - val_loss: 1.2861 - val_acc: 0.4762
# Epoch 286/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1254 - acc: 0.9592 - val_loss: 1.3173 - val_acc: 0.4643
# Epoch 287/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1264 - acc: 0.9694 - val_loss: 1.2660 - val_acc: 0.4762
# Epoch 288/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1416 - acc: 0.9592 - val_loss: 1.1919 - val_acc: 0.4881
# Epoch 289/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.0920 - acc: 0.9745 - val_loss: 1.2530 - val_acc: 0.5000
# Epoch 290/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1751 - acc: 0.9082 - val_loss: 1.3769 - val_acc: 0.4881
# Epoch 291/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1362 - acc: 0.9490 - val_loss: 1.2303 - val_acc: 0.4762
# Epoch 292/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1238 - acc: 0.9592 - val_loss: 1.3943 - val_acc: 0.4643
# Epoch 293/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1121 - acc: 0.9643 - val_loss: 1.2383 - val_acc: 0.4762
# Epoch 294/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1421 - acc: 0.9643 - val_loss: 1.2984 - val_acc: 0.5000
# Epoch 295/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1342 - acc: 0.9643 - val_loss: 1.3439 - val_acc: 0.4881
# Epoch 296/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.0801 - acc: 0.9847 - val_loss: 1.3735 - val_acc: 0.4762
# Epoch 297/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1322 - acc: 0.9694 - val_loss: 1.2574 - val_acc: 0.5000
# Epoch 298/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1083 - acc: 0.9745 - val_loss: 1.3220 - val_acc: 0.5119
# Epoch 299/300
# 196/196 [==============================] - 0s 2ms/sample - loss: 0.1476 - acc: 0.9490 - val_loss: 1.1978 - val_acc: 0.4881
# Epoch 300/300
# 196/196 [==============================] - 1s 3ms/sample - loss: 0.1117 - acc: 0.9643 - val_loss: 1.2751 - val_acc: 0.5119

# %%
# cross validation
'''
#learning_rate = 0.01,num_epochs = 500, minibatch_size = 16
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report
skf=StratifiedKFold(n_splits=5)
skf.get_n_splits(X,b)
print(skf)
for train_index,test_index in skf.split(X,b):
    #print("Train Index:",train_index,",Test Index:",test_index)
    X_train,X_test=X[train_index],X[test_index]
    y_train,y_test=Y[train_index],Y[test_index]
    
    X_train = X_train/255.
    X_test = X_test/255.
    print ("number of training examples = " + str(X_train.shape[0]))
    print ("number of test examples = " + str(X_test.shape[0]))
#     print ("X_train shape: " + str(X_train.shape))
#     print ("Y_train shape: " + str(y_train.shape))
#     print ("X_test shape: " + str(X_test.shape))
#     print ("Y_test shape: " + str(y_test.shape))
    
    _, _, parameters = model(X_train, y_train, X_test, y_test)
    
    
    with open('2003.pkl','rb') as f:
            pred=pickle.load(f)
            
    true=np.argmax(y_test,1)+1
    confusion_matrix(true,pred)
    print(classification_report(true,pred))
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-aed75b2a3d3e> in <module>()
#       5 from sklearn.metrics import confusion_matrix, classification_report
#       6 skf=StratifiedKFold(n_splits=5)
# ----> 7 skf.get_n_splits(X,b)
#       8 print(skf)
#       9 for train_index,test_index in skf.split(X,b):
#
# NameError: name 'b' is not defined

# %%
#  Visualization of training process
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(0)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
plt.ylim(0,1)

plt.figure(1)
plt.plot(history.history['loss'])

plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
